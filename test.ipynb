# %%
import random
import operator

operations = {
    '+': operator.add,
    '-': operator.sub,
    '*': operator.mul,
    '/': operator.truediv
}

def random_expression(numbers, operations):
    expr = [random.choice(numbers)]
    for _ in range(3):
        operation = random.choice(list(operations.keys()))
        number = random.choice(numbers)
        expr += [operation, number]
    return expr

def evaluate_expression(expr):
    result = expr[0]
    for i in range(1, len(expr), 2):
        operation = operations[expr[i]]
        next_value = expr[i+1]
        if operation == operations['/'] and next_value == 0:
            return float('inf')
        result = operation(result, next_value)
    return result

def fitness(expr, target):
    result = evaluate_expression(expr)
    if result == float('inf'):
        return 0
    return 1 / (1 + abs(result - target))

def mutate(expr, numbers, operations, mutation_rate=0.1):
    if random.random() < mutation_rate:
        idx = random.randint(0, len(expr) - 1)
        if idx % 2 == 0:
            expr[idx] = random.choice(numbers)
        else:
            expr[idx] = random.choice(list(operations.keys()))
    return expr

def crossover(parent1, parent2):
    point = random.randint(1, min(len(parent1), len(parent2)) - 1)
    child = parent1[:point] + parent2[point:]
    return child

def selection(population, target, top_k=5):
    sorted_pop = sorted(population, key=lambda x: -fitness(x, target))
    return sorted_pop[:top_k]

def genetic_algorithm(numbers, target, max_generations=100):
    population = [random_expression(numbers, operations) for _ in range(20)]
    for generation in range(max_generations):
        population = selection(population, target)
        new_population = []
        for i in range(len(population)):
            child = mutate(crossover(population[i], population[(i + 1) % len(population)]), numbers, operations)
            new_population.append(child)
        population = new_population
        print(f"Generation {generation} best fitness: {fitness(population[0], target)}")
    
    best_solution = population[0]
    print("Best solution after all generations:", best_solution, "with value:", evaluate_expression(best_solution))
    return best_solution

# Example usage
numbers = [25, 50, 75, 100, 3, 6, 0]  # Added zero to test the handling of division by zero
target_number = 952
solution = genetic_algorithm(numbers, target_number)
print("Final Solution:", solution, "Value:", evaluate_expression(solution))
# Out:
# Generation 0 best fitness: 0.0011111111111111111
# Generation 1 best fitness: 0.0010504643052229084
# Generation 2 best fitness: 0.001172497889503799
# Generation 3 best fitness: 0.0011075668970405813
# Generation 4 best fitness: 0.001422475106685633
# Generation 5 best fitness: 0.0013736263736263737
# Generation 6 best fitness: 0.001524390243902439
# Generation 7 best fitness: 0.001107493299665537
# Generation 8 best fitness: 0.0011078286558345643
# Generation 9 best fitness: 0.0010779734099892204
# Generation 10 best fitness: 0.0010776791102681267
# Generation 11 best fitness: 0.0010779734099892204
# Generation 12 best fitness: 0.0010787486515641855
# Generation 13 best fitness: 0.0011123470522803114
# Generation 14 best fitness: 0.0010787486515641855
# Generation 15 best fitness: 0.0010493197050488229
# Generation 16 best fitness: 0.0010779734099892204
# Generation 17 best fitness: 0.0010560108135507307
# Generation 18 best fitness: 0.0010563380281690142
# Generation 19 best fitness: 0.0011009174311926604
# Generation 20 best fitness: 0.0010783608914450035
# Generation 21 best fitness: 0.001077632656580025
# Generation 22 best fitness: 0
# Generation 23 best fitness: 0.0010560554217885355
# Generation 24 best fitness: 0.0011002068388857105
# Generation 25 best fitness: 0.0010776791102681267
# Generation 26 best fitness: 0.0010494500881538073
# Generation 27 best fitness: 0.0010496850944716586
# Generation 28 best fitness: 0.0010627444312191804
# Generation 29 best fitness: 0.001084645754696516
# Generation 30 best fitness: 0.0010846928149947936
# Generation 31 best fitness: 0.0010846928149947936
# Generation 32 best fitness: 0.001084645754696516
# Generation 33 best fitness: 0.0010593669223272172
# Generation 34 best fitness: 0.0010634526763559022
# Generation 35 best fitness: 0.0010779734099892204
# Generation 36 best fitness: 0.0010563380281690142
# Generation 37 best fitness: 0.0010562140593827014
# Generation 38 best fitness: 0.0010563380281690142
# Generation 39 best fitness: 0.0010559810768191035
# Generation 40 best fitness: 0.0010562140593827014
# Generation 41 best fitness: 0.001053740779768177
# Generation 42 best fitness: 0.0010527202290719218
# Generation 43 best fitness: 0.0012033694344163659
# Generation 44 best fitness: 0.0012406947890818859
# Generation 45 best fitness: 0.0012033694344163659
# Generation 46 best fitness: 0.0012406947890818859
# Generation 47 best fitness: 0.0012033694344163659
# Generation 48 best fitness: 0.0011498658489842851
# Generation 49 best fitness: 0.0011177347242921013
# Generation 50 best fitness: 0.0011498658489842851
# Generation 51 best fitness: 0.0011177347242921013
# Generation 52 best fitness: 0.0011075559931085404
# Generation 53 best fitness: 0.0011089548100914888
# Generation 54 best fitness: 0.0010790396547073105
# Generation 55 best fitness: 0.0009737098344693282
# Generation 56 best fitness: 0.0010619469026548673
# Generation 57 best fitness: 0.0011148272017837235
# Generation 58 best fitness: 0.0013227513227513227
# Generation 59 best fitness: 0.0012804097311139564
# Generation 60 best fitness: 0.0013227513227513227
# Generation 61 best fitness: 0.0012453300124533001
# Generation 62 best fitness: 0.00125
# Generation 63 best fitness: 0.0012804097311139564
# Generation 64 best fitness: 0.0013227513227513227
# Generation 65 best fitness: 0.0012406947890818859
# Generation 66 best fitness: 0.0012453300124533001
# Generation 67 best fitness: 0.00125
# Generation 68 best fitness: 0.0012804097311139564
# Generation 69 best fitness: 0.0013227513227513227
# Generation 70 best fitness: 0.0013679890560875513
# Generation 71 best fitness: 0.0012903225806451613
# Generation 72 best fitness: 0.0012903225806451613
# Generation 73 best fitness: 0.00125
# Generation 74 best fitness: 0.0012853470437017994
# Generation 75 best fitness: 0.00125
# Generation 76 best fitness: 0.0012853470437017994
# Generation 77 best fitness: 0.00125
# Generation 78 best fitness: 0
# Generation 79 best fitness: 0.0013227513227513227
# Generation 80 best fitness: 0.0013679890560875513
# Generation 81 best fitness: 0.001142857142857143
# Generation 82 best fitness: 0.0013679890560875513
# Generation 83 best fitness: 0.0013227513227513227
# Generation 84 best fitness: 0.0013679890560875513
# Generation 85 best fitness: 0.0012804097311139564
# Generation 86 best fitness: 0.0012804097311139564
# Generation 87 best fitness: 0.0012804097311139564
# Generation 88 best fitness: 0.0013679890560875513
# Generation 89 best fitness: 0.0013679890560875513
# Generation 90 best fitness: 0.0013227513227513227
# Generation 91 best fitness: 0.0012853470437017994
# Generation 92 best fitness: 0.00125
# Generation 93 best fitness: 0.0012853470437017994
# Generation 94 best fitness: 0.0012453300124533001
# Generation 95 best fitness: 0.0013679890560875513
# Generation 96 best fitness: 0.0012853470437017994
# Generation 97 best fitness: 0.0012853470437017994
# Generation 98 best fitness: 0.0012853470437017994
# Generation 99 best fitness: 0.0012853470437017994
# Best solution after all generations: [100, '+', 75, '-', 3, '+', 3] with value: 175
# Final Solution: [100, '+', 75, '-', 3, '+', 3] Value: 175

# %%
import random
import operator

# Operators and their corresponding functions
operations = {
    '+': operator.add,
    '-': operator.sub,
    '*': operator.mul,
    '/': operator.truediv
}

def random_expression(numbers, operations):
    """Generate a random valid expression as a list of numbers and operation symbols"""
    expr = [random.choice(numbers)]  # Start with a random number
    for _ in range(3):  # Limit the length of the expression for simplicity
        operation = random.choice(list(operations.keys()))
        number = random.choice(numbers)
        expr += [operation, number]  # Append operation followed by number
    return expr

def evaluate_expression(expr):
    """Evaluate the numerical expression handling operators correctly"""
    result = expr[0]
    for i in range(1, len(expr), 2):
        operation = operations[expr[i]]
        next_value = expr[i+1]
        if operation == operations['/'] and next_value == 0:
            return float('inf')  # Return a large number for division by zero cases
        result = operation(result, next_value)
    return result


def fitness(expr, target):
    """Fitness is inversely proportional to the difference from the target"""
    result = evaluate_expression(expr)
    return 1 / (1 + abs(result - target))

def mutate(expr, numbers, operations, mutation_rate=0.1):
    if random.random() < mutation_rate:
        idx = random.randint(0, len(expr) - 1)
        if idx % 2 == 0:  # Index of a number
            expr[idx] = random.choice(numbers)
        else:  # Index of an operator
            expr[idx] = random.choice(list(operations.keys()))
    return expr

def crossover(parent1, parent2):
    """Crossover at random point to create a new expression"""
    point = random.randint(1, min(len(parent1), len(parent2)) - 1)
    child = parent1[:point] + parent2[point:]
    return child

def selection(population, target, top_k=5):
    sorted_pop = sorted(population, key=lambda x: -fitness(x, target))
    return sorted_pop[:top_k]

def genetic_algorithm(numbers, target, max_generations=100):
    population = [random_expression(numbers, operations) for _ in range(20)]  # Initialize with a larger population

    for generation in range(max_generations):
        population = selection(population, target)
        new_population = []
        for i in range(len(population)):
            child = mutate(crossover(population[i], population[(i + 1) % len(population)]), numbers, operations)
            new_population.append(child)
        population = new_population

        # Debug: Print current best solution
        print(f"Generation {generation} best fitness: {fitness(population[0], target)}")
    
    best_solution = population[0]
    print("Best solution after all generations:", best_solution, "with value:", evaluate_expression(best_solution))
    return best_solution

# Example usage
numbers = [25, 50, 75, 100, 3, 6]
target_number = 952
solution = genetic_algorithm(numbers, target_number)
print("Final Solution:", solution, "Value:", evaluate_expression(solution))
# Out:
# Generation 0 best fitness: 0.0010822510822510823
# Generation 1 best fitness: 0.0010775862068965517
# Generation 2 best fitness: 0.0010737294201861132
# Generation 3 best fitness: 0.001095690284879474
# Generation 4 best fitness: 0.0010615711252653928
# Generation 5 best fitness: 0.0010660980810234541
# Generation 6 best fitness: 0.0010522008534518032
# Generation 7 best fitness: 0.0010857763300760044
# Generation 8 best fitness: 0.001095690284879474
# Generation 9 best fitness: 0.001185302252074279
# Generation 10 best fitness: 0.0011641443538998836
# Generation 11 best fitness: 0.0010775862068965517
# Generation 12 best fitness: 0.001049317943336831
# Generation 13 best fitness: 0.0010775862068965517
# Generation 14 best fitness: 0.0010775862068965517
# Generation 15 best fitness: 0.0011641443538998836
# Generation 16 best fitness: 0.0010507880910683013
# Generation 17 best fitness: 0.0010499643012137588
# Generation 18 best fitness: 0.0010503319048819426
# Generation 19 best fitness: 0.0010495626822157433
# Generation 20 best fitness: 0.001075268817204301
# Generation 21 best fitness: 0.001053740779768177
# Generation 22 best fitness: 0.0010491858317945274
# Generation 23 best fitness: 0.0010480861946086447
# Generation 24 best fitness: 0.0010491858317945274
# Generation 25 best fitness: 0.001072961373390558
# Generation 26 best fitness: 0.001072961373390558
# Generation 27 best fitness: 0.001072961373390558
# Generation 28 best fitness: 0.001072961373390558
# Generation 29 best fitness: 0.001072961373390558
# Generation 30 best fitness: 0.001072961373390558
# Generation 31 best fitness: 0.001072961373390558
# Generation 32 best fitness: 0.0010826416456153013
# Generation 33 best fitness: 0.0010826416456153013
# Generation 34 best fitness: 0.0010706638115631692
# Generation 35 best fitness: 0.0010826416456153013
# Generation 36 best fitness: 0.0011682242990654205
# Generation 37 best fitness: 0.0011682242990654205
# Generation 38 best fitness: 0.0011682242990654205
# Generation 39 best fitness: 0.0011312217194570137
# Generation 40 best fitness: 0.001160092807424594
# Generation 41 best fitness: 0.001160092807424594
# Generation 42 best fitness: 0.0011312217194570137
# Generation 43 best fitness: 0.001160092807424594
# Generation 44 best fitness: 0.001160092807424594
# Generation 45 best fitness: 0.0010427528675703858
# Generation 46 best fitness: 0.0010741138560687433
# Generation 47 best fitness: 0.0010964912280701754
# Generation 48 best fitness: 0.0011273957158962795
# Generation 49 best fitness: 0.0011235955056179776
# Generation 50 best fitness: 0.0011273957158962795
# Generation 51 best fitness: 0.001160092807424594
# Generation 52 best fitness: 0.0011312217194570137
# Generation 53 best fitness: 0.001160092807424594
# Generation 54 best fitness: 0.001160092807424594
# Generation 55 best fitness: 0.0011560693641618498
# Generation 56 best fitness: 0.0011560693641618498
# Generation 57 best fitness: 0.0011560693641618498
# Generation 58 best fitness: 0.0011560693641618498
# Generation 59 best fitness: 0.0011560693641618498
# Generation 60 best fitness: 0.0011560693641618498
# Generation 61 best fitness: 0.0011560693641618498
# Generation 62 best fitness: 0.0011560693641618498
# Generation 63 best fitness: 0.0011560693641618498
# Generation 64 best fitness: 0.0011560693641618498
# Generation 65 best fitness: 0.0011560693641618498
# Generation 66 best fitness: 0.0011560693641618498
# Generation 67 best fitness: 0.0010638297872340426
# Generation 68 best fitness: 0.001160092807424594
# Generation 69 best fitness: 0.001160092807424594
# Generation 70 best fitness: 0.0011560693641618498
# Generation 71 best fitness: 0.0011682242990654205
# Generation 72 best fitness: 0.0011682242990654205
# Generation 73 best fitness: 0.0011641443538998836
# Generation 74 best fitness: 0.0011682242990654205
# Generation 75 best fitness: 0.0011682242990654205
# Generation 76 best fitness: 0.0011641443538998836
# Generation 77 best fitness: 0.0011682242990654205
# Generation 78 best fitness: 0.0011682242990654205
# Generation 79 best fitness: 0.0011682242990654205
# Generation 80 best fitness: 0.0011389521640091116
# Generation 81 best fitness: 0.0011682242990654205
# Generation 82 best fitness: 0.0011682242990654205
# Generation 83 best fitness: 0.0011389521640091116
# Generation 84 best fitness: 0.001176470588235294
# Generation 85 best fitness: 0.001176470588235294
# Generation 86 best fitness: 0.0012121212121212121
# Generation 87 best fitness: 0.0012453300124533001
# Generation 88 best fitness: 0.0012121212121212121
# Generation 89 best fitness: 0.0010897203051216855
# Generation 90 best fitness: 0.0010702818408847663
# Generation 91 best fitness: 0.0010608203677510608
# Generation 92 best fitness: 0.0010702818408847663
# Generation 93 best fitness: 0.0010897203051216855
# Generation 94 best fitness: 0.0010516574120814403
# Generation 95 best fitness: 0.00105000105000105
# Generation 96 best fitness: 0.0010516574120814403
# Generation 97 best fitness: 0.00105000105000105
# Generation 98 best fitness: 0.0010521442700223054
# Generation 99 best fitness: 0.0011086474501108647
# Best solution after all generations: [100, '+', 3, '+', 50, '/', 3] with value: 51.0
# Final Solution: [100, '+', 3, '+', 50, '/', 3] Value: 51.0

# %%
import unittest

class TestSolveNumbersAndGeneticAlgorithm(unittest.TestCase):
    def test_solve_numbers_basic(self):
        numbers = [25, 10, 2, 8, 1, 5]
        target = 100
        result = solve_numbers(numbers, target)
        self.assertIsNotNone(result, "Should find a solution")
        self.assertEqual(eval(result), target, "The expression should evaluate to the target.")

    def test_solve_numbers_no_solution(self):
        numbers = [1, 3, 5]
        target = 100
        result = solve_numbers(numbers, target)
        self.assertEqual(result, "No valid solution found", "Should return no solution message when impossible.")

    def test_genetic_algorithm_basic(self):
        numbers = [25, 50, 75, 100, 3, 6]
        target = 952
        expression = genetic_algorithm(numbers, target)
        solution = evaluate_expression(expression)
        self.assertTrue(abs(solution - target) <= 10, "The solution should be close to the target within a margin.")

    def test_genetic_algorithm_handles_zero(self):
        numbers = [0, 25, 50, 75]
        target = 10
        expression = genetic_algorithm(numbers, target)
        solution = evaluate_expression(expression)
        self.assertTrue(abs(solution - target) <= 10, "The solution should handle zero without errors and be close to the target.")

# Optionally add more tests based on your specific needs

# %%
if __name__ == "__main__":
    unittest.main(argv=[''], exit=False)  # Adjustments for Jupyter notebook to run unittests.
# Out:
# FF.F
# ======================================================================
# FAIL: test_genetic_algorithm_basic (__main__.TestSolveNumbersAndGeneticAlgorithm.test_genetic_algorithm_basic)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\shaun\AppData\Local\Temp\ipykernel_14784\3740102799.py", line 22, in test_genetic_algorithm_basic
#     self.assertTrue(abs(solution - target) <= 10, "The solution should be close to the target within a margin.")
# AssertionError: False is not true : The solution should be close to the target within a margin.
#
# ======================================================================
# FAIL: test_genetic_algorithm_handles_zero (__main__.TestSolveNumbersAndGeneticAlgorithm.test_genetic_algorithm_handles_zero)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\shaun\AppData\Local\Temp\ipykernel_14784\3740102799.py", line 29, in test_genetic_algorithm_handles_zero
#     self.assertTrue(abs(solution - target) <= 10, "The solution should handle zero without errors and be close to the target.")
# AssertionError: False is not true : The solution should handle zero without errors and be close to the target.
#
# ======================================================================
# FAIL: test_solve_numbers_no_solution (__main__.TestSolveNumbersAndGeneticAlgorithm.test_solve_numbers_no_solution)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\shaun\AppData\Local\Temp\ipykernel_14784\3740102799.py", line 15, in test_solve_numbers_no_solution
#     self.assertEqual(result, "No valid solution found", "Should return no solution message when impossible.")
# AssertionError: '((5 * 3) * 5)' != 'No valid solution found'
# - ((5 * 3) * 5)
# + No valid solution found
#  : Should return no solution message when impossible.
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.017s
#
# FAILED (failures=3)
# Generation 0 best fitness: 0.0010494170488293754
# Generation 1 best fitness: 0.0015923566878980893
# Generation 2 best fitness: 0.00021281123643328368
# Generation 3 best fitness: 0.001142857142857143
# Generation 4 best fitness: 0.00023261223540358222
# Generation 5 best fitness: 0.00021281123643328368
# Generation 6 best fitness: 0.0012453300124533001
# Generation 7 best fitness: 0.0011389521640091116
# Generation 8 best fitness: 0.0013736263736263737
# Generation 9 best fitness: 0.0011074197120708748
# Generation 10 best fitness: 0.00021281123643328368
# Generation 11 best fitness: 0.0012987012987012987
# Generation 12 best fitness: 0.00141643059490085
# Generation 13 best fitness: 0.0013679890560875513
# Generation 14 best fitness: 0.002
# Generation 15 best fitness: 0.0024813895781637717
# Generation 16 best fitness: 0.001142857142857143
# Generation 17 best fitness: 0.0011876484560570072
# Generation 18 best fitness: 0.0011750881316098707
# Generation 19 best fitness: 0.0011876484560570072
# Generation 20 best fitness: 0.0011409013120365088
# Generation 21 best fitness: 0.0011876484560570072
# Generation 22 best fitness: 0.0017857142857142857
# Generation 23 best fitness: 0.0017857142857142857
# Generation 24 best fitness: 0.001869158878504673
# Generation 25 best fitness: 0.0017857142857142857
# Generation 26 best fitness: 0.001869158878504673
# Generation 27 best fitness: 0.0017857142857142857
# Generation 28 best fitness: 0.0017857142857142857
# Generation 29 best fitness: 0.001869158878504673
# Generation 30 best fitness: 0.0017857142857142857
# Generation 31 best fitness: 0.001869158878504673
# Generation 32 best fitness: 0.0017857142857142857
# Generation 33 best fitness: 0.0017857142857142857
# Generation 34 best fitness: 0.001869158878504673
# Generation 35 best fitness: 0.0017857142857142857
# Generation 36 best fitness: 0.001639344262295082
# Generation 37 best fitness: 0.0016778523489932886
# Generation 38 best fitness: 0.0015479876160990713
# Generation 39 best fitness: 0.0017513134851138354
# Generation 40 best fitness: 0.0011467889908256881
# Generation 41 best fitness: 0.0009813542688910696
# Generation 42 best fitness: 0.0011389521640091116
# Generation 43 best fitness: 0.0011389521640091116
# Generation 44 best fitness: 0.0011273957158962795
# Generation 45 best fitness: 0.0011467889908256881
# Generation 46 best fitness: 0.0010626992561105207
# Generation 47 best fitness: 0.002336448598130841
# Generation 48 best fitness: 0.002012072434607646
# Generation 49 best fitness: 0.0024813895781637717
# Generation 50 best fitness: 0.002336448598130841
# Generation 51 best fitness: 0.002012072434607646
# Generation 52 best fitness: 0.002336448598130841
# Generation 53 best fitness: 0.0024813895781637717
# Generation 54 best fitness: 0.002336448598130841
# Generation 55 best fitness: 0.002336448598130841
# Generation 56 best fitness: 0.0024813895781637717
# Generation 57 best fitness: 0.0011391857100544532
# Generation 58 best fitness: 0.0011391857100544532
# Generation 59 best fitness: 0.0011391857100544532
# Generation 60 best fitness: 0.0010643959552953698
# Generation 61 best fitness: 0.001189767995240928
# Generation 62 best fitness: 0.0011391857100544532
# Generation 63 best fitness: 0.0011725803803850755
# Generation 64 best fitness: 0.0011391857100544532
# Generation 65 best fitness: 0.0011391857100544532
# Generation 66 best fitness: 0.0010561000337952012
# Generation 67 best fitness: 0.0011391857100544532
# Generation 68 best fitness: 0.0011391078507313073
# Generation 69 best fitness: 0.0011391078507313073
# Generation 70 best fitness: 0.0011402508551881414
# Generation 71 best fitness: 0.0011391078507313073
# Generation 72 best fitness: 0.0011391078507313073
# Generation 73 best fitness: 0.0011391078507313073
# Generation 74 best fitness: 0.001142857142857143
# Generation 75 best fitness: 0.001142857142857143
# Generation 76 best fitness: 0.001440922190201729
# Generation 77 best fitness: 0.0005636978579481398
# Generation 78 best fitness: 0.0011391857100544532
# Generation 79 best fitness: 0.0012077294685990338
# Generation 80 best fitness: 0.0012077294685990338
# Generation 81 best fitness: 0.0012453300124533001
# Generation 82 best fitness: 0.0021676300578034684
# Generation 83 best fitness: 0.0012077294685990338
# Generation 84 best fitness: 0.0011723329425556857
# Generation 85 best fitness: 0.001142857142857143
# Generation 86 best fitness: 0.001142857142857143
# Generation 87 best fitness: 0.001142857142857143
# Generation 88 best fitness: 0.0011750881316098707
# Generation 89 best fitness: 0.001142857142857143
# Generation 90 best fitness: 0.001142857142857143
# Generation 91 best fitness: 0.001142857142857143
# Generation 92 best fitness: 0.0011750881316098707
# Generation 93 best fitness: 0.001059322033898305
# Generation 94 best fitness: 0.001142857142857143
# Generation 95 best fitness: 0.0010559662090813093
# Generation 96 best fitness: 0.0010845986984815619
# Generation 97 best fitness: 0.0010869565217391304
# Generation 98 best fitness: 0.0010869565217391304
# Generation 99 best fitness: 0.0011806375442739079
# Best solution after all generations: [100, '/', 3, '*', 3, '+', 6] with value: 106.0
# Generation 0 best fitness: 0.0
# Generation 1 best fitness: 0.09124087591240876
# Generation 2 best fitness: 0.09191176470588235
# Generation 3 best fitness: 0.09124087591240876
# Generation 4 best fitness: 0.09090909090909091
# Generation 5 best fitness: 0.09090909090909091
# Generation 6 best fitness: 0.09090909090909091
# Generation 7 best fitness: 0.09090909090909091
# Generation 8 best fitness: 3.555669336974339e-06
# Generation 9 best fitness: 3.555669336974339e-06
# Generation 10 best fitness: 0.09090909090909091
# Generation 11 best fitness: 0.09090909090909091
# Generation 12 best fitness: 0.09090909090909091
# Generation 13 best fitness: 0.09090909090909091
# Generation 14 best fitness: 0.09090909090909091
# Generation 15 best fitness: 0.09090909090909091
# Generation 16 best fitness: 0.09090909090909091
# Generation 17 best fitness: 0.09090909090909091
# Generation 18 best fitness: 0.09090909090909091
# Generation 19 best fitness: 0.0
# Generation 20 best fitness: 8.000576041474985e-06
# Generation 21 best fitness: 0.0
# Generation 22 best fitness: 0.0
# Generation 23 best fitness: 3.555669336974339e-06
# Generation 24 best fitness: 3.555669336974339e-06
# Generation 25 best fitness: 0.0005359056806002144
# Generation 26 best fitness: 3.555669336974339e-06
# Generation 27 best fitness: 0.0
# Generation 28 best fitness: 0.0
# Generation 29 best fitness: 0.0
# Generation 30 best fitness: 0.0
# Generation 31 best fitness: 0.0
# Generation 32 best fitness: 0.0
# Generation 33 best fitness: 0.0
# Generation 34 best fitness: 0.0
# Generation 35 best fitness: 0.0
# Generation 36 best fitness: 0.0
# Generation 37 best fitness: 0.0
# Generation 38 best fitness: 0.0
# Generation 39 best fitness: 0.0
# Generation 40 best fitness: 0.0
# Generation 41 best fitness: 0.0
# Generation 42 best fitness: 0.0
# Generation 43 best fitness: 0.0
# Generation 44 best fitness: 0.0
# Generation 45 best fitness: 0.0
# Generation 46 best fitness: 0.0
# Generation 47 best fitness: 0.0
# Generation 48 best fitness: 0.0
# Generation 49 best fitness: 0.0
# Generation 50 best fitness: 0.0
# Generation 51 best fitness: 0.0
# Generation 52 best fitness: 0.09090909090909091
# Generation 53 best fitness: 0.03508771929824561
# Generation 54 best fitness: 0.0002673082063619353
# Generation 55 best fitness: 0.00017806267806267807
# Generation 56 best fitness: 0.0002673082063619353
# Generation 57 best fitness: 0.09090909090909091
# Generation 58 best fitness: 0.0
# Generation 59 best fitness: 0.0
# Generation 60 best fitness: 0.0
# Generation 61 best fitness: 0.0
# Generation 62 best fitness: 0.0
# Generation 63 best fitness: 0.0
# Generation 64 best fitness: 0.0
# Generation 65 best fitness: 0.0
# Generation 66 best fitness: 0.0
# Generation 67 best fitness: 0.0
# Generation 68 best fitness: 0.0
# Generation 69 best fitness: 0.0
# Generation 70 best fitness: 0.0
# Generation 71 best fitness: 0.0
# Generation 72 best fitness: 0.0
# Generation 73 best fitness: 0.0
# Generation 74 best fitness: 0.0
# Generation 75 best fitness: 0.0
# Generation 76 best fitness: 0.0
# Generation 77 best fitness: 0.0
# Generation 78 best fitness: 0.0
# Generation 79 best fitness: 0.0
# Generation 80 best fitness: 0.09090909090909091
# Generation 81 best fitness: 0.0
# Generation 82 best fitness: 0.0
# Generation 83 best fitness: 0.0
# Generation 84 best fitness: 0.09090909090909091
# Generation 85 best fitness: 0.011627906976744186
# Generation 86 best fitness: 0.09090909090909091
# Generation 87 best fitness: 0.011627906976744186
# Generation 88 best fitness: 0.09090909090909091
# Generation 89 best fitness: 0.09090909090909091
# Generation 90 best fitness: 0.09090909090909091
# Generation 91 best fitness: 0.09090909090909091
# Generation 92 best fitness: 0.09090909090909091
# Generation 93 best fitness: 0.09090909090909091
# Generation 94 best fitness: 0.011627906976744186
# Generation 95 best fitness: 0.011627906976744186
# Generation 96 best fitness: 0.09090909090909091
# Generation 97 best fitness: 0.09090909090909091
# Generation 98 best fitness: 0.09090909090909091
# Generation 99 best fitness: 0.027777777777777776
# Best solution after all generations: [25, '/', 50, '*', 0, '-', 25] with value: -25.0
